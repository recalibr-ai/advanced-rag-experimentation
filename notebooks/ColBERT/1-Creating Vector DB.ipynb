# %% [markdown]
# # Exploring Data

# %%
import pandas as pd

# %%
reviews = pd.read_csv("../data/restaurant_reviews.csv")

# %%
# Display the full 'review' column without truncation
pd.set_option('display.max_colwidth', None)
reviews.sample(5)
# Out:
#     id              restaurant  \
# 5    6      Starbucks Downtown
# 11  12           Family Garden
# 3    4         Le Bernardin SF
# 2    3           Code & Coffee
# 4    5  Tony's Italian Kitchen
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 review  \
# ...
